# %% [markdown]
# # Healthy Communities Data and Indicators Project (HCI)
#
# Healthy Communities Data and Indicators Project (HCI)

# %%
from ambry import get_library
l = get_library()
b = l.bundle('cdph.ca.gov-hci-0.0.4')
p = b.partition('cdph.ca.gov-hci-unemployment-county')

# %%
p
# Out:
# <partition: p04p00a004 cdph.ca.gov-hci-unemployment-county-0.0.4>
